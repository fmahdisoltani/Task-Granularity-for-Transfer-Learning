# %%
import torch
from torch.autograd import Variable

# %%
k = Variable(torch.LongTensor([0]))

# %%
dir(k)
# Out:
# ['__add__',
#  '__bool__',
#  '__class__',
#  '__deepcopy__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__idiv__',
#  '__imul__',
#  '__init__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
#  '__pow__',
#  '__radd__',
#  '__rdiv__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__setattr__',
#  '__setitem__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__weakref__',
#  '_add',
#  '_addcop',
#  '_advanced_index_add',
#  '_backward_hooks',
#  '_blas',
#  '_execution_engine',
#  '_fallthrough_methods',
# ...

# %%
k.expand(5,1)
# Out:
# Variable containing:
#  0
#  0
#  0
#  0
#  0
# [torch.LongTensor of size 5x1]

# %%
l = torch.ones(6,1).byte()

# %%
l.sum()
# Out:
# 6

# %%
k*l
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-18-1db86303f83d> in <module>()
# ----> 1 k*l
#
# ~/venv/lib/python3.5/site-packages/torch/autograd/variable.py in __mul__(self, other)
#     827
#     828     def __mul__(self, other):
# --> 829         return self.mul(other)
#     830     __rmul__ = __mul__
#     831
#
# ~/venv/lib/python3.5/site-packages/torch/autograd/variable.py in mul(self, other)
#     339             return Mul.apply(self, other)
#     340         else:
# --> 341             assert not torch.is_tensor(other)
#     342             return MulConstant.apply(self, other)
#     343
#
# AssertionError:
